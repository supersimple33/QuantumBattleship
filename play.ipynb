# %%
import gymnasium as gym
import numpy as np
from battleship import BattleshipEnv

# %%
env = BattleshipEnv()
env.reset()
env.render('2d')

# %%
x = env.step(7 + 10 * 0)
env.render('2d')

# %%
"Done", x[2]
# Out:
# ('Done', True)

# %%
"Score", np.sum(x[0])
# Out:
# ('Score', 56)
